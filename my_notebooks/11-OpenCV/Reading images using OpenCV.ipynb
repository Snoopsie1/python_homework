# %%
import cv2
import sys
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import Image

np.set_printoptions(threshold=sys.maxsize)


Image(filename="images/capy_128x128.jpeg")

# %%
capy_img = cv2.imread("images/capy_128x128.jpeg", 0)
print(capy_img)
# Out:
# [[229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229
#   229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229
#   229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229
#   229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229
#   229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229
#   229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229
#   229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229
#   229 229]
#  [229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229
#   229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229
#   229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229
#   229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229
#   229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229
# ...

# %%
# Print the size of image
print("Image size is ", capy_img.shape)

# Print data-type of image
print("Data type of image is ", capy_img.dtype)
# Out:
# Image size is  (128, 128)
# Data type of image is  uint8

# %%
# Display image.
plt.imshow(capy_img)

# %%
# Set color map to gray scale for black/white rendering
plt.imshow(capy_img, cmap='gray')

# %%
# Read image as gray scale.
capy_img_fuzzy = cv2.imread("images/capy_128x128.jpeg", 0)

# Print image
print(capy_img_fuzzy)

# Display image.
plt.imshow(capy_img_fuzzy, cmap='gray')
# Out:
# [[229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229
#   229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229
#   229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229
#   229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229
#   229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229
#   229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229
#   229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229
#   229 229]
#  [229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229
#   229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229
#   229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229
#   229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229
#   229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229 229
# ...
